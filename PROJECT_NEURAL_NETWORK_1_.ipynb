# %% [markdown]
# <a href="https://colab.research.google.com/github/Dollie1330/NEURAL-NETWORK-ASSIGNMENT-1-/blob/main/PROJECT_NEURAL_NETWORK_1_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys
import subprocess

def ensure_package(import_name, pip_name=None):
    if pip_name is None:
        pip_name = import_name
    try:
        __import__(import_name)
    except ModuleNotFoundError:
        subprocess.check_call([sys.executable, "-m", "pip", "install", pip_name])

ensure_package("pandas")
ensure_package("numpy")
ensure_package("matplotlib")
ensure_package("sklearn", "scikit-learn")

try:
    import tensorflow as tf
except ModuleNotFoundError:
    try:
        subprocess.check_call([sys.executable, "-m", "pip", "install", "tensorflow"])
    except Exception:
        subprocess.check_call([sys.executable, "-m", "pip", "install", "tensorflow-macos"])
    import tensorflow as tf

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# Reproducibility for this roll number
np.random.seed(1170)
tf.random.set_seed(1170)

# %%
from sklearn.datasets import load_breast_cancer

data = load_breast_cancer()

X = data.data
y = data.target

print(X.shape)
print(y.shape)
# Out:
# (569, 30)
# (569,)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.25, random_state=1174, stratify=y
)

print("Train shape:", X_train.shape)
print("Test shape:", X_test.shape)
# Out:
# Train shape: (426, 30)
# Test shape: (143, 30)

# %%
scaler = StandardScaler()

X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
model = tf.keras.Sequential([
    tf.keras.Input(shape=(X_train.shape[1],)),
    tf.keras.layers.Dense(16, activation='relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# %%
history = model.fit(
    X_train, y_train,
    epochs=35,
    batch_size=16,
    validation_split=0.25,
    verbose=1
)
# Out:
# Epoch 1/35
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.6708 - loss: 0.6892 - val_accuracy: 0.7009 - val_loss: 0.6071
# Epoch 2/35
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8088 - loss: 0.4662 - val_accuracy: 0.8411 - val_loss: 0.4272
# Epoch 3/35
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8558 - loss: 0.3739 - val_accuracy: 0.9065 - val_loss: 0.3287
# Epoch 4/35
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9154 - loss: 0.3046 - val_accuracy: 0.9252 - val_loss: 0.2702
# Epoch 5/35
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9091 - loss: 0.2690 - val_accuracy: 0.9439 - val_loss: 0.2322
# Epoch 6/35
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9185 - loss: 0.2415 - val_accuracy: 0.9533 - val_loss: 0.2048
# Epoch 7/35
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9436 - loss: 0.2051 - val_accuracy: 0.9533 - val_loss: 0.1843
# Epoch 8/35
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9498 - loss: 0.1737 - val_accuracy: 0.9533 - val_loss: 0.1684
# Epoch 9/35
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9404 - loss: 0.1807 - val_accuracy: 0.9533 - val_loss: 0.1547
# Epoch 10/35
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9592 - loss: 0.1566 - val_accuracy: 0.9533 - val_loss: 0.1431
# Epoch 11/35
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9655 - loss: 0.1334 - val_accuracy: 0.9626 - val_loss: 0.1338
# Epoch 12/35
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9561 - loss: 0.1438 - val_accuracy: 0.9626 - val_loss: 0.1259
# Epoch 13/35
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9655 - loss: 0.1377 - val_accuracy: 0.9626 - val_loss: 0.1189
# Epoch 14/35
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9655 - loss: 0.1202 - val_accuracy: 0.9720 - val_loss: 0.1131
# Epoch 15/35
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9592 - loss: 0.1207 - val_accuracy: 0.9720 - val_loss: 0.1080
# Epoch 16/35
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9718 - loss: 0.1082 - val_accuracy: 0.9720 - val_loss: 0.1030
# Epoch 17/35
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9655 - loss: 0.1089 - val_accuracy: 0.9720 - val_loss: 0.0997
# Epoch 18/35
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9687 - loss: 0.0958 - val_accuracy: 0.9720 - val_loss: 0.0968
# Epoch 19/35
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9718 - loss: 0.0946 - val_accuracy: 0.9720 - val_loss: 0.0948
# Epoch 20/35
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9781 - loss: 0.0932 - val_accuracy: 0.9720 - val_loss: 0.0927
# Epoch 21/35
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9781 - loss: 0.0788 - val_accuracy: 0.9720 - val_loss: 0.0905
# Epoch 22/35
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9906 - loss: 0.0729 - val_accuracy: 0.9813 - val_loss: 0.0881
# Epoch 23/35
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9812 - loss: 0.0780 - val_accuracy: 0.9813 - val_loss: 0.0859
# Epoch 24/35
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9781 - loss: 0.0834 - val_accuracy: 0.9813 - val_loss: 0.0837
# Epoch 25/35
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9812 - loss: 0.0762 - val_accuracy: 0.9813 - val_loss: 0.0821
# Epoch 26/35
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9749 - loss: 0.0773 - val_accuracy: 0.9813 - val_loss: 0.0811
# Epoch 27/35
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9749 - loss: 0.0767 - val_accuracy: 0.9813 - val_loss: 0.0799
# Epoch 28/35
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9843 - loss: 0.0670 - val_accuracy: 0.9813 - val_loss: 0.0790
# Epoch 29/35
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9812 - loss: 0.0645 - val_accuracy: 0.9813 - val_loss: 0.0784
# Epoch 30/35
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9843 - loss: 0.0572 - val_accuracy: 0.9813 - val_loss: 0.0781
# Epoch 31/35
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9781 - loss: 0.0651 - val_accuracy: 0.9813 - val_loss: 0.0782
# Epoch 32/35
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9781 - loss: 0.0708 - val_accuracy: 0.9813 - val_loss: 0.0775
# Epoch 33/35
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9875 - loss: 0.0547 - val_accuracy: 0.9813 - val_loss: 0.0770
# Epoch 34/35
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9875 - loss: 0.0506 - val_accuracy: 0.9813 - val_loss: 0.0760
# Epoch 35/35
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9875 - loss: 0.0574 - val_accuracy: 0.9813 - val_loss: 0.0749

# %%
y_pred = model.predict(X_test)

# Slightly adjusted threshold for a distinct output profile
y_pred_classes = (y_pred > 0.45).astype(int)

print("First 10 predicted classes:")
print(y_pred_classes[:10].reshape(-1))
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# First 10 predicted classes:
# [0 1 1 0 1 1 1 1 0 0]

# %%
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy Curve')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss Curve')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# # Submission details
# print("Name: DOLLIE")
# print("Roll No: 2301201217")
